# %% [markdown]
# # The Battle of Neighborhood- Final Report (Week 2)¶
# # Mediterranean restaurants in Germany
# __1. Introduction and Busniness problem__
#
# __Problem Background__
#
# During last decades have many people decided to immigrate mainly for security und financial reasons. To the list of the common immigration countries was Germany added. Because of the instability in the middle east caused by the so called arab spring, peaple from all age categories have leaved their countries legally or illegally to the nearest safe continent, namely Europe. The European union have failed to find solution to devide the immigrants from middle east and north Afrika equally between the european countries. Therefore each country made his own decision.
#
# For financial , demographic and humanitarian reasons landed the most part of the immigrants in Germany. This peaple comme from other cultures, speak other languages and have other caracteristics. This open new investment opportunities like language courses, Translater, clothings , special spices, Integration courses...etc
#
# __Problem description__
#
# Opening a Restaurant in Germany is a business that could make high profit and make immigrants feeling like at home. The is some factors that must be taken in consideration in order to open a successful restaurant:
#
# Repartition of immigrants in Germany Cuisines that immigrants likely enjoy Repartions of similiar restaurant in Germany We need to find the best location to open a restaurant.
#
# __2. Data__
#
# Data 1:
# The number of Habitants coming from Mediterranean countries in their repartition in Germany. This Data is provided for free in [Mediterranean population in Germany](https://www-genesis.destatis.de/genesis/online?operation=statistic&levelindex=0&levelid=1593532730678&code=12521#abreadcrumb)
#
# Data 2:
# The cities in each State [Cities in Baden-Württemberg](https://de.wikipedia.org/wiki/Liste_der_Land-_und_Stadtkreise_in_Baden-W%C3%BCrttemberg)
#
# Data 3:
#
# The venues , their locations and their categories . This is provided in Foursquare for free.
#
# __3. Methodology__
#
# __Business Undestanding__
#
# The main goal of this project is to find the best location in Germany to open a Restaurant which specialised in mediterranean cuisine.
#
# __Analytic Approach__
#
# In ordner to find the best place to open a Restaurant for mediterranean we will first try to find out where the mediterranean people are most located. In second part we will look what kind and how much restaurants are provided in the region where the mediterranean people live.
#
# __Exploratory Data Analysis__
#
# Data 1: Mediterranean Population in Germany
#
# The provided Data represents all people in Germany who come from other countries from all over the world, their age , gender and State.
#
# <img src="sc1.png"/>
#
# In order to extract only Information about peaple from the Mediterranean region, we first made a list the countries located in the region.
#
# <img src="sc2.png"/>
#
# Afer eliminating irrelevant countries and since the Gender and status don't influence the results, we have added all columns of the Table over each row ( each country) to get the total number of from this country living in Germany. After that we grouped all colums by State in order to get the repartition of mediterranean people in Germany over the States, like the folowing table shows.
#
# <img src="sc3.png"/>
#
# Data 2: The effective surface in each State
#
# In order to calculate the density of this people in each State, we need Informations about the area where they leave. Since there is in some states more forest, industries..etx than others, we have taken into account only Surfaces where peaple can live and spend free time and go eat. After substructing the irrelvant surfaces we have this summerized the Data in the folowing Table. here are the relevant surfaces in each State.
#
# <img src="sc4.png"/>
#
# Then we added all this surfaces over the States
#
# <img src="sc5.png"/>
#
# Since we have the effective surface of each state and the number of mediterreanean peaple in each speace we can now calculte the densitiy of this peaple in each State
#
# <img src="sc6.png"/>
#
# As we see this Data has different ranges. This may be inconvenient for the visualisation. Therefore this Data need to be normalized.
#
# <img src="sc7.png"/>
#
# Then we can visualise this Data.
#
# <img src="sc8.png"/>
#
# Insights from this Data:
#
# 1. Nordrhein-Westfale, Baden-Württemberg, Bayern and Hessen are the States the most mediterranean Population
# 2. In Hessen and Baden-Württemberg is the ratio Density over Area larger
# 3. The largest ratio Density over Area is in Baden-Württemberg.
#
# Data 3: Mediterranean Restaurants in Baden-Württemberg
#
# In the folowing we well analyse Data related to the State Baden-Württemberg in order to find out which city is well suited for an new Restaurant for mediterranean cuisine.
# Since the state is too big to fetch all relevant restaurants localted in it. We choose to analayse the Data of restaurants located in the urban districts of Baden-Württemberg. This make sense because also immigrants generelly prefer living in cities and not in villages. Therefo in the center of each cities will engender the most restaurants and relevant venues.
#
# Here is a list of the urban districts in Baden-Württemberg.
#
# <img src="sc9.png"/>
#
# With the geolocator we get the longitude and the latitude of each urban district in order use ist for fetching informatiosn about venues from fouresquare
#
# <img src="sc10.png"/>
#
# Using fouresquare we exctract all venues in the listed urban district within a radius of 10 Km and a limit of 1000 results.
#
# <img src="sc11.png"/>
#
# This Data frame has 161 unique venue category. Then we filter by restaurant in order to get only food venues. Then filter out the restaurants that are irrelevant for mediterranean people. then we get 12 unique venue categories.
#
#
# <img src="sc12.png"/>
#
# <img src="sc13.png"/>
#
# After that we grouped the Venues by urban districts
#
#
#
# __Results:__
#
#
#
# 1. Stuttgart, Mannheim, Karlsruhe and Heidelberg most relevant venues
# 2. Geographically Mannheim and Heidelberg near to each other. Therfore the number of restaurants can be added.
# 3. Stuttgart is a bigger urban district and isolated from the other ones.
#
# <img src="sc14.png"/>
#
# <img src="sc15.png"/>
#
#
# __Discusssion:__
#
# 1. opening a Restaurant near Heidelberg or Mannheim is quiet Riscky. But of we can get information about mediterranean people living there, we can make better decision.
# 2. Stuttgart ist a good location for new restautant
# 3. Freigburg is relativlely small city. There is also quit riscky to open a Restaurant.
# 4. Mediterranean and Middle East specialities could be succesfull.
# 5. Italian specialities are well provided ,so it's also risky to start such business.
#
#
# __Conclusion:__
#
# The analysis of this Data my be wrong or incomplet since other larger information could be needed and better assumptions could be made. But with the provided analysis we can guarantee that a new restaurtant in Stuttgart for mediteranean specialities could be succesfull.

# %% [markdown]
# ![](sc.png)
